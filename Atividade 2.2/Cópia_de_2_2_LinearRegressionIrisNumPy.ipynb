# %% [markdown]
# # Regressão Linear com NumPy

# %% [markdown]
# ## Objetivos deste experimento

# %% [markdown]
# Este exemplo utiliza regressão linear para estimar o comprimento das sépalas da íris a partir do seu comprimento das pétalas.
# Utiliza-se programação totalmente NumPy com:
# - o **cálculo do gradiente**,
# - a **função de perda** e
# - a atualização dos parâmetros são feitos de forma explícita.
# - A rede é criada com uma camada como uma classe

# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/vcasadei/images/master/RegressaoLinear_Otimizacao.png)

# %% [markdown]
# ## Importação dos pacotes

# %%
# %matplotlib inline
import matplotlib.pyplot as plt   # para plotting

from sklearn.datasets import load_iris  # para carregar dataset

import numpy as np  # processamento matricial

np.random.seed(1234)

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### Leitura dos dados

# %%
iris = load_iris()
data = iris.data[iris.target==1,::2]  # comprimento das sépalas e pétalas, indices 0 e 2

x_train = data[:,0:1]
y_train = data[:,1:2]

n_samples = x_train.shape[0]
print('x_train.shape:',x_train.shape, x_train.dtype)
print('y_train.shape:',y_train.shape, y_train.dtype)

print('x_train[:5]:\n', x_train[:5])
print('y_train[:5]:\n', y_train[:5])
# Out:
# x_train.shape: (50, 1) float64
# y_train.shape: (50, 1) float64
# x_train[:5]:
#  [[7. ]
#  [6.4]
#  [6.9]
#  [5.5]
#  [6.5]]
# y_train[:5]:
#  [[4.7]
#  [4.5]
#  [4.9]
#  [4. ]
#  [4.6]]

# %% [markdown]
# ### Normalização dos dados

# %%
x_train -= x_train.min()
x_train /= x_train.max()
y_train -= y_train.min()
y_train /= y_train.max()

# %%
plt.scatter(x_train,y_train)
plt.xlabel('Comprimento sepalas')
plt.ylabel('Comprimento petalas')
# Out:
# Text(0, 0.5, 'Comprimento petalas')

# %% [markdown]
# ## Modelo da rede

# %% [markdown]
# ### Reta de ajuste

# %% [markdown]
# A equação da reta no plano necessita de dois parâmetros, aqui denominados $w_0$ (*bias*) e inclinação $w_1$. Veja figura:
#
# ![alt text](https://raw.githubusercontent.com/vcasadei/images/master/linhareta.png)
#
# A reta de ajuste será dada por:
#
# $$ \hat{y} = w_0 + w_1 x $$
#
# onde
# * $w_1$ é o coeficiente angular da reta e
# * $w_0$ é a interseção do eixo vertical quando x é igual a zero, também denominado de *bias*.
# * $x$ é a variável de entrada (comprimento das sépalas) e
# * $\hat{y}$ é a predição (comprimento estimado das pétalas).

# %% [markdown]
# ### Linear Regression Model

# %% [markdown]
# ![alt text](https://raw.githubusercontent.com/vcasadei/images/master/RegressaoLinearNeuronio.png)

# %% [markdown]
# ### Formulação matricial do neurônio

# %% [markdown]
# * $\mathbf{w} = [w_0 \ w_1]$ é vetor linha de parâmetros e
# * $\mathbf{x} = [1 \ x_0] $ é vetor linha de uma amostra (com *bias*).
#
# $$ \hat{y} = 1 w_0 + x_0 w_1 $$
#
# $$ [\hat{y}] = [1 \ x_0] \begin{bmatrix} w_0 \\ w_1 \end{bmatrix} $$
#
# $$ \mathbf{\hat{y}} = \mathbf{x} \mathbf{w^T} $$

# %% [markdown]
# ### Fazendo o predict de várias amostras

# %% [markdown]
# $$ \begin{matrix}
# \begin{bmatrix}
# \hat{y}_0\\
# \hat{y}_1\\
# \\
# \hat{y}_{M-1}
# \end{bmatrix} &=& \begin{bmatrix}
# 1 & x_0 \\
# 1 & x_1\\
# \\
# 1 & x_{M-1} \\
# \end{bmatrix}
# &
# \begin{bmatrix}
# w_0\\
# w_1
# \end{bmatrix} \\
# (M,1) & & (M,2) & (2,1) \\
# \end{matrix} $$

# %% [markdown]
# ### Preenchendo x com coluna de 1's para bias

# %%
x_train_bias = np.hstack([np.ones(shape=(n_samples,1)), x_train])

# %%
x_train_bias
# Out:
# array([[1.        , 1.        ],
#        [1.        , 0.71428571],
#        [1.        , 0.95238095],
#        [1.        , 0.28571429],
#        [1.        , 0.76190476],
#        [1.        , 0.38095238],
#        [1.        , 0.66666667],
#        [1.        , 0.        ],
#        [1.        , 0.80952381],
#        [1.        , 0.14285714],
#        [1.        , 0.04761905],
#        [1.        , 0.47619048],
#        [1.        , 0.52380952],
#        [1.        , 0.57142857],
#        [1.        , 0.33333333],
#        [1.        , 0.85714286],
#        [1.        , 0.33333333],
#        [1.        , 0.42857143],
#        [1.        , 0.61904762],
#        [1.        , 0.33333333],
#        [1.        , 0.47619048],
#        [1.        , 0.57142857],
#        [1.        , 0.66666667],
#        [1.        , 0.57142857],
#        [1.        , 0.71428571],
#        [1.        , 0.80952381],
#        [1.        , 0.9047619 ],
#        [1.        , 0.85714286],
#        [1.        , 0.52380952],
#        [1.        , 0.38095238],
#        [1.        , 0.28571429],
#        [1.        , 0.28571429],
#        [1.        , 0.42857143],
#        [1.        , 0.52380952],
#        [1.        , 0.23809524],
#        [1.        , 0.52380952],
#        [1.        , 0.85714286],
#        [1.        , 0.66666667],
#        [1.        , 0.33333333],
#        [1.        , 0.28571429],
#        [1.        , 0.28571429],
#        [1.        , 0.57142857],
#        [1.        , 0.42857143],
#        [1.        , 0.04761905],
#        [1.        , 0.33333333],
#        [1.        , 0.38095238],
#        [1.        , 0.38095238],
#        [1.        , 0.61904762],
#        [1.        , 0.0952381 ],
#        [1.        , 0.38095238]])

# %% [markdown]
# ### Classe com o modelo da rede

# %%
class Net():
    def __init__(self, n_in, n_out):
        self.w = np.random.uniform(-0.1,0.1,(n_out,n_in)) #inicialização dos parâmetros

    def forward(self, x_bias):
        return x_bias.dot(self.w.T)

# %% [markdown]
# ### Criando a rede, instanciando o objeto model

# %%
model = Net(2,1) # duas entradas (1 + x0) e uma saída y_pred

# %% [markdown]
# ### Testando o predict da rede (mesmo sem treiná-la)

# %%
xin = np.random.randn(4,2) # 4 amostras, 2 entradas (1 + x0)
ypred = model.forward(xin)
ypred
# Out:
# array([[-0.09602795],
#        [ 0.0661236 ],
#        [-0.06857828],
#        [-0.05573871]])

# %% [markdown]
# ## Treinamento via gradiente descendente

# %% [markdown]
# Função de perda:
# $$ J(\hat{y_i},y_i) = \frac{1}{M} \sum_{i=0}^{M-1} (\hat{y_i} - y_i)^2 $$

# %% [markdown]
# Gradiente:
# $$  \mathbf{\nabla{J_w}} = \frac{2}{M}\mathbf{x^T}(\mathbf{x w^T} - \mathbf{y}) $$

# %% [markdown]
# Atualização dos parâmetros pelo gradiente descendente:
# $$ \mathbf{w} = \mathbf{w} − \eta (\mathbf{\nabla J_w})^T $$

# %% [markdown]
# ### Laço de treinamento

# %%
num_epochs = 100
learning_rate = 0.5
for epoch in range(num_epochs):

    # forward - predict
    y_pred = model.forward(x_train_bias)

    #loss cálculo da função de perda
    loss = np.square(y_pred - y_train).mean()

    # cálculo do gradiente pelas derivadas parciais
    w_grad = (2.0/n_samples) * (x_train_bias.T).dot(x_train_bias.dot(model.w.T) - y_train)

    # gradiente descendente
    model.w = model.w - learning_rate * w_grad.T

    # verbose
    if (epoch+1) % 1 == 0:
        print('Epoch[{}/{}], loss: {:.6f}'
              .format(epoch+1, num_epochs, loss))
# Out:
# Epoch[1/100], loss: 0.469163
# Epoch[2/100], loss: 0.058070
# Epoch[3/100], loss: 0.030543
# Epoch[4/100], loss: 0.028105
# Epoch[5/100], loss: 0.027364
# Epoch[6/100], loss: 0.026787
# Epoch[7/100], loss: 0.026269
# Epoch[8/100], loss: 0.025799
# Epoch[9/100], loss: 0.025373
# Epoch[10/100], loss: 0.024986
# Epoch[11/100], loss: 0.024634
# Epoch[12/100], loss: 0.024315
# Epoch[13/100], loss: 0.024025
# Epoch[14/100], loss: 0.023762
# Epoch[15/100], loss: 0.023524
# Epoch[16/100], loss: 0.023307
# Epoch[17/100], loss: 0.023110
# Epoch[18/100], loss: 0.022931
# Epoch[19/100], loss: 0.022769
# Epoch[20/100], loss: 0.022622
# Epoch[21/100], loss: 0.022488
# Epoch[22/100], loss: 0.022366
# Epoch[23/100], loss: 0.022256
# Epoch[24/100], loss: 0.022156
# Epoch[25/100], loss: 0.022065
# Epoch[26/100], loss: 0.021983
# Epoch[27/100], loss: 0.021908
# Epoch[28/100], loss: 0.021840
# Epoch[29/100], loss: 0.021778
# Epoch[30/100], loss: 0.021722
# Epoch[31/100], loss: 0.021671
# Epoch[32/100], loss: 0.021625
# Epoch[33/100], loss: 0.021583
# Epoch[34/100], loss: 0.021545
# Epoch[35/100], loss: 0.021510
# Epoch[36/100], loss: 0.021479
# Epoch[37/100], loss: 0.021450
# Epoch[38/100], loss: 0.021425
# Epoch[39/100], loss: 0.021401
# Epoch[40/100], loss: 0.021380
# Epoch[41/100], loss: 0.021360
# Epoch[42/100], loss: 0.021343
# Epoch[43/100], loss: 0.021327
# Epoch[44/100], loss: 0.021312
# Epoch[45/100], loss: 0.021299
# Epoch[46/100], loss: 0.021287
# Epoch[47/100], loss: 0.021276
# Epoch[48/100], loss: 0.021267
# Epoch[49/100], loss: 0.021258
# Epoch[50/100], loss: 0.021249
# Epoch[51/100], loss: 0.021242
# Epoch[52/100], loss: 0.021235
# Epoch[53/100], loss: 0.021229
# Epoch[54/100], loss: 0.021224
# Epoch[55/100], loss: 0.021219
# Epoch[56/100], loss: 0.021214
# Epoch[57/100], loss: 0.021210
# Epoch[58/100], loss: 0.021206
# Epoch[59/100], loss: 0.021203
# Epoch[60/100], loss: 0.021200
# Epoch[61/100], loss: 0.021197
# Epoch[62/100], loss: 0.021195
# Epoch[63/100], loss: 0.021192
# Epoch[64/100], loss: 0.021190
# Epoch[65/100], loss: 0.021188
# Epoch[66/100], loss: 0.021186
# Epoch[67/100], loss: 0.021185
# Epoch[68/100], loss: 0.021183
# Epoch[69/100], loss: 0.021182
# Epoch[70/100], loss: 0.021181
# Epoch[71/100], loss: 0.021180
# Epoch[72/100], loss: 0.021179
# Epoch[73/100], loss: 0.021178
# Epoch[74/100], loss: 0.021177
# Epoch[75/100], loss: 0.021177
# Epoch[76/100], loss: 0.021176
# Epoch[77/100], loss: 0.021175
# Epoch[78/100], loss: 0.021175
# Epoch[79/100], loss: 0.021174
# Epoch[80/100], loss: 0.021174
# Epoch[81/100], loss: 0.021173
# Epoch[82/100], loss: 0.021173
# Epoch[83/100], loss: 0.021173
# Epoch[84/100], loss: 0.021172
# Epoch[85/100], loss: 0.021172
# Epoch[86/100], loss: 0.021172
# Epoch[87/100], loss: 0.021172
# Epoch[88/100], loss: 0.021171
# Epoch[89/100], loss: 0.021171
# Epoch[90/100], loss: 0.021171
# Epoch[91/100], loss: 0.021171
# Epoch[92/100], loss: 0.021171
# Epoch[93/100], loss: 0.021171
# Epoch[94/100], loss: 0.021171
# Epoch[95/100], loss: 0.021170
# Epoch[96/100], loss: 0.021170
# Epoch[97/100], loss: 0.021170
# Epoch[98/100], loss: 0.021170
# Epoch[99/100], loss: 0.021170
# Epoch[100/100], loss: 0.021170

# %% [markdown]
# ## Avaliação

# %% [markdown]
# ### Predict

# %%
y_pred = model.forward(x_train_bias)
plt.plot(x_train, y_train, 'ro', label='Original data')
plt.plot(x_train, y_pred, 'kx-', label='Fitting Line')

# %% [markdown]
# ### Parâmetros treinados

# %%
print(model.w)
# Out:
# [[0.26295353 0.68335641]]

# %% [markdown]
# ### Avaliação do modelo

# %%
loss = np.square(y_pred - y_train).mean()
loss
# Out:
# np.float64(0.02117000379151052)

# %% [markdown]
# ### Valor ótimo, solução analítica

# %% [markdown]
# $$  \mathbf{w} =(\mathbf{x^T} \mathbf{x})^{−1}\mathbf{x^T} \mathbf{y} $$

# %%
x = x_train_bias
y = y_train
w_opt = (np.linalg.inv((x.T).dot(x)).dot(x.T)).dot(y)
print(w_opt.T)
# Out:
# [[0.26134159 0.68646976]]

# %% [markdown]
# # Exercícios

# %% [markdown]
# ## Questões

# %% [markdown]
# 1. Quantos parâmetros são treinados nesse modelo?
#
# RESPOSTA: 2, w0 e w1
#
# 2. Qual é o número de atributos de entrada para a rede?
#
# RESPOSTA: 2, (bias e x)
#
# 3. Qual é o número de saídas da rede?
#
# RESPOSTA: 1, y
#
# 4. Suponha que eu tenha agora 5 mil amostras para fazer a predição. Qual é o shape da matriz de entrada?
#    Qual é o shape do matriz de saída?
#
# RESPOSTA: Entrada [5k,2]
# Saída [5k,1]

# %% [markdown]
# ## Atividades (entrega dia 24/05)

# %% [markdown]
# 1. Modifique o laço do treinamento via gradiente descendente para guardar em uma lista, o valor da perda no final
#    de cada época. Após o treinamento, plote o valor da perda em função da época.
# 2. Calcule o valor da perda (MSE) da rede com os parâmetros inicializados, sem serem treinados.
# 3. Coloque os valores dos pesos da solução ótima analítica no modelo da rede e calcule o valor da perda (MSE) e
#    compare com o valor da perda obtida pelo método da otimização via gradiente descendente.

# %% [markdown]
# # Aprendizados

# %%
# 1 Modifique o laço do treinamento via gradiente descendente para guardar em uma lista, o valor da perda no final

perdas = []

num_epochs = 100
learning_rate = 0.5
for epoch in range(num_epochs):

    # forward - predict
    y_pred = model.forward(x_train_bias)

    #loss cálculo da função de perda
    loss = np.square(y_pred - y_train).mean()
    perdas.append(loss)

    # cálculo do gradiente pelas derivadas parciais
    w_grad = (2.0/n_samples) * (x_train_bias.T).dot(x_train_bias.dot(model.w.T) - y_train)

    # gradiente descendente
    model.w = model.w - learning_rate * w_grad.T

    # verbose
    if (epoch+1) % 1 == 0:
        print('Epoch[{}/{}], loss: {:.6f}'
              .format(epoch+1, num_epochs, loss))
# Out:
# Epoch[1/100], loss: 0.021170
# Epoch[2/100], loss: 0.021170
# Epoch[3/100], loss: 0.021170
# Epoch[4/100], loss: 0.021170
# Epoch[5/100], loss: 0.021170
# Epoch[6/100], loss: 0.021170
# Epoch[7/100], loss: 0.021170
# Epoch[8/100], loss: 0.021170
# Epoch[9/100], loss: 0.021170
# Epoch[10/100], loss: 0.021170
# Epoch[11/100], loss: 0.021170
# Epoch[12/100], loss: 0.021170
# Epoch[13/100], loss: 0.021170
# Epoch[14/100], loss: 0.021170
# Epoch[15/100], loss: 0.021170
# Epoch[16/100], loss: 0.021170
# Epoch[17/100], loss: 0.021170
# Epoch[18/100], loss: 0.021170
# Epoch[19/100], loss: 0.021170
# Epoch[20/100], loss: 0.021170
# Epoch[21/100], loss: 0.021170
# Epoch[22/100], loss: 0.021170
# Epoch[23/100], loss: 0.021169
# Epoch[24/100], loss: 0.021169
# Epoch[25/100], loss: 0.021169
# Epoch[26/100], loss: 0.021169
# Epoch[27/100], loss: 0.021169
# Epoch[28/100], loss: 0.021169
# Epoch[29/100], loss: 0.021169
# Epoch[30/100], loss: 0.021169
# Epoch[31/100], loss: 0.021169
# Epoch[32/100], loss: 0.021169
# Epoch[33/100], loss: 0.021169
# Epoch[34/100], loss: 0.021169
# Epoch[35/100], loss: 0.021169
# Epoch[36/100], loss: 0.021169
# Epoch[37/100], loss: 0.021169
# Epoch[38/100], loss: 0.021169
# Epoch[39/100], loss: 0.021169
# Epoch[40/100], loss: 0.021169
# Epoch[41/100], loss: 0.021169
# Epoch[42/100], loss: 0.021169
# Epoch[43/100], loss: 0.021169
# Epoch[44/100], loss: 0.021169
# Epoch[45/100], loss: 0.021169
# Epoch[46/100], loss: 0.021169
# Epoch[47/100], loss: 0.021169
# Epoch[48/100], loss: 0.021169
# Epoch[49/100], loss: 0.021169
# Epoch[50/100], loss: 0.021169
# Epoch[51/100], loss: 0.021169
# Epoch[52/100], loss: 0.021169
# Epoch[53/100], loss: 0.021169
# Epoch[54/100], loss: 0.021169
# Epoch[55/100], loss: 0.021169
# Epoch[56/100], loss: 0.021169
# Epoch[57/100], loss: 0.021169
# Epoch[58/100], loss: 0.021169
# Epoch[59/100], loss: 0.021169
# Epoch[60/100], loss: 0.021169
# Epoch[61/100], loss: 0.021169
# Epoch[62/100], loss: 0.021169
# Epoch[63/100], loss: 0.021169
# Epoch[64/100], loss: 0.021169
# Epoch[65/100], loss: 0.021169
# Epoch[66/100], loss: 0.021169
# Epoch[67/100], loss: 0.021169
# Epoch[68/100], loss: 0.021169
# Epoch[69/100], loss: 0.021169
# Epoch[70/100], loss: 0.021169
# Epoch[71/100], loss: 0.021169
# Epoch[72/100], loss: 0.021169
# Epoch[73/100], loss: 0.021169
# Epoch[74/100], loss: 0.021169
# Epoch[75/100], loss: 0.021169
# Epoch[76/100], loss: 0.021169
# Epoch[77/100], loss: 0.021169
# Epoch[78/100], loss: 0.021169
# Epoch[79/100], loss: 0.021169
# Epoch[80/100], loss: 0.021169
# Epoch[81/100], loss: 0.021169
# Epoch[82/100], loss: 0.021169
# Epoch[83/100], loss: 0.021169
# Epoch[84/100], loss: 0.021169
# Epoch[85/100], loss: 0.021169
# Epoch[86/100], loss: 0.021169
# Epoch[87/100], loss: 0.021169
# Epoch[88/100], loss: 0.021169
# Epoch[89/100], loss: 0.021169
# Epoch[90/100], loss: 0.021169
# Epoch[91/100], loss: 0.021169
# Epoch[92/100], loss: 0.021169
# Epoch[93/100], loss: 0.021169
# Epoch[94/100], loss: 0.021169
# Epoch[95/100], loss: 0.021169
# Epoch[96/100], loss: 0.021169
# Epoch[97/100], loss: 0.021169
# Epoch[98/100], loss: 0.021169
# Epoch[99/100], loss: 0.021169
# Epoch[100/100], loss: 0.021169

# %%
perdas
# Out:
# [np.float64(0.02117000379151052),
#  np.float64(0.02116995040474736),
#  np.float64(0.02116990193480691),
#  np.float64(0.021169857928858827),
#  np.float64(0.021169817975777626),
#  np.float64(0.021169781702301722),
#  np.float64(0.021169748769546245),
#  np.float64(0.021169718869836967),
#  np.float64(0.021169691723835923),
#  np.float64(0.021169667077931654),
#  np.float64(0.021169644701869838),
#  np.float64(0.021169624386602165),
#  np.float64(0.021169605942333282),
#  np.float64(0.02116958919674764),
#  np.float64(0.02116957399339963),
#  np.float64(0.02116956019025202),
#  np.float64(0.021169547658348917),
#  np.float64(0.02116953628061104),
#  np.float64(0.021169525950741893),
#  np.float64(0.021169516572234696),
#  np.float64(0.02116950805747077),
#  np.float64(0.021169500326900938),
#  np.float64(0.02116949330830237),
#  np.float64(0.021169486936103817),
#  np.float64(0.021169481150773037),
#  np.float64(0.021169475898260574),
#  np.float64(0.021169471129494858),
#  np.float64(0.02116946679992369),
#  np.float64(0.021169462869098064),
#  np.float64(0.02116945930029425),
#  np.float64(0.0211694560601707),
#  np.float64(0.021169453118456572),
#  np.float64(0.02116945044766891),
#  np.float64(0.021169448022855867),
#  np.float64(0.02116944582136366),
#  np.float64(0.021169443822624825),
#  np.float64(0.02116944200796617),
#  np.float64(0.021169440360434232),
#  np.float64(0.021169438864636958),
#  np.float64(0.021169437506599862),
#  np.float64(0.021169436273635482),
#  np.float64(0.02116943515422486),
#  np.float64(0.021169434137909896),
#  np.float64(0.021169433215195665),
#  np.float64(0.02116943237746172),
#  np.float64(0.02116943161688153),
#  np.float64(0.02116943092634938),
#  np.float64(0.02116943029941398),
#  np.float64(0.021169429730218164),
#  np.float64(0.021169429213444238),
#  np.float64(0.02116942874426424),
#  np.float64(0.021169428318294867),
#  np.float64(0.021169427931556475),
#  np.float64(0.021169427580435985),
#  np.float64(0.021169427261653048),
#  np.float64(0.021169426972229427),
#  np.float64(0.021169426709461193),
#  np.float64(0.021169426470893433),
#  np.float64(0.021169426254297317),
#  np.float64(0.02116942605764931),
#  np.float64(0.021169425879112226),
#  np.float64(0.021169425717018072),
#  np.float64(0.021169425569852494),
#  np.float64(0.021169425436240594),
#  np.float64(0.02116942531493411),
#  np.float64(0.021169425204799724),
#  np.float64(0.02116942510480851),
#  np.float64(0.021169425014026313),
#  np.float64(0.02116942493160498),
#  np.float64(0.02116942485677451),
#  np.float64(0.021169424788835777),
#  np.float64(0.02116942472715409),
#  np.float64(0.02116942467115316),
#  np.float64(0.021169424620309817),
#  np.float64(0.021169424574149054),
#  np.float64(0.02116942453223961),
#  np.float64(0.021169424494189952),
#  np.float64(0.0211694244596446),
#  np.float64(0.021169424428280802),
#  np.float64(0.02116942439980556),
#  np.float64(0.021169424373952826),
#  np.float64(0.021169424350481095),
#  np.float64(0.02116942432917106),
#  np.float64(0.021169424309823638),
#  np.float64(0.02116942429225808),
#  np.float64(0.02116942427631028),
#  np.float64(0.021169424261831243),
#  np.float64(0.02116942424868569),
#  np.float64(0.02116942423675083),
#  np.float64(0.021169424225915147),
#  np.float64(0.0211694242160774),
#  np.float64(0.021169424207145696),
#  np.float64(0.021169424199036592),
#  np.float64(0.021169424191674314),
#  np.float64(0.021169424184990092),
#  np.float64(0.021169424178921474),
#  np.float64(0.02116942417341177),
#  np.float64(0.021169424168409487),
#  np.float64(0.021169424163867915),
#  np.float64(0.021169424159744613)]

# %%
plt.plot(perdas, color = 'r', marker = 'o')
plt.title('Perda por época')
plt.xlabel('Épocas')
plt.ylabel('Perda')
plt.show()

# %%
# 2 Calcule o valor da perda (MSE) da rede com os parâmetros inicializados, sem serem treinados.

model = Net(2,1) # duas entradas (1 + x0) e uma saída y_pred
model.w

ypred = model.forward(x_train_bias)
loss = np.square(ypred - y_train).mean()
loss
# Out:
# np.float64(0.39512226382971893)

# %%
# 3 Coloque os valores dos pesos da solução ótima analítica no modelo da rede
# e calcule o valor da perda (MSE) e compare com o valor da perda obtida pelo método da otimização via gradiente descendente.

#valor ótimo analítico
x = x_train_bias
y = y_train
w_opt = (np.linalg.inv((x.T).dot(x)).dot(x.T)).dot(y)
print(w_opt.T)
# Out:
# [[0.26134159 0.68646976]]

# %%
model = Net(2,1)
model.w = w_opt.T
model.w
# Out:
# array([[0.26134159, 0.68646976]])

# %%
y_pred = model.forward(x_train_bias)
loss_otimo = np.square(y_pred - y_train).mean()
loss_otimo
# Out:
# np.float64(0.021169424119097165)

# %%
model = Net(2,1)
perdas = []

num_epochs = 100
learning_rate = 0.5
for epoch in range(num_epochs):

    # forward - predict
    y_pred = model.forward(x_train_bias)

    #loss cálculo da função de perda
    loss = np.square(y_pred - y_train).mean()
    perdas.append(loss)

    # cálculo do gradiente pelas derivadas parciais
    w_grad = (2.0/n_samples) * (x_train_bias.T).dot(x_train_bias.dot(model.w.T) - y_train)

    # gradiente descendente
    model.w = model.w - learning_rate * w_grad.T

    # verbose
    if (epoch+1) % 1 == 0:
        print('Epoch[{}/{}], loss: {:.6f}'
              .format(epoch+1, num_epochs, loss))
# Out:
# Epoch[1/100], loss: 0.333644
# Epoch[2/100], loss: 0.052919
# Epoch[3/100], loss: 0.033558
# Epoch[4/100], loss: 0.031344
# Epoch[5/100], loss: 0.030337
# Epoch[6/100], loss: 0.029488
# Epoch[7/100], loss: 0.028722
# Epoch[8/100], loss: 0.028026
# Epoch[9/100], loss: 0.027395
# Epoch[10/100], loss: 0.026821
# Epoch[11/100], loss: 0.026301
# Epoch[12/100], loss: 0.025828
# Epoch[13/100], loss: 0.025399
# Epoch[14/100], loss: 0.025010
# Epoch[15/100], loss: 0.024656
# Epoch[16/100], loss: 0.024335
# Epoch[17/100], loss: 0.024043
# Epoch[18/100], loss: 0.023779
# Epoch[19/100], loss: 0.023538
# Epoch[20/100], loss: 0.023320
# Epoch[21/100], loss: 0.023122
# Epoch[22/100], loss: 0.022942
# Epoch[23/100], loss: 0.022779
# Epoch[24/100], loss: 0.022631
# Epoch[25/100], loss: 0.022496
# Epoch[26/100], loss: 0.022374
# Epoch[27/100], loss: 0.022263
# Epoch[28/100], loss: 0.022162
# Epoch[29/100], loss: 0.022071
# Epoch[30/100], loss: 0.021988
# Epoch[31/100], loss: 0.021912
# Epoch[32/100], loss: 0.021844
# Epoch[33/100], loss: 0.021782
# Epoch[34/100], loss: 0.021725
# Epoch[35/100], loss: 0.021674
# Epoch[36/100], loss: 0.021628
# Epoch[37/100], loss: 0.021586
# Epoch[38/100], loss: 0.021547
# Epoch[39/100], loss: 0.021512
# Epoch[40/100], loss: 0.021481
# Epoch[41/100], loss: 0.021452
# Epoch[42/100], loss: 0.021426
# Epoch[43/100], loss: 0.021402
# Epoch[44/100], loss: 0.021381
# Epoch[45/100], loss: 0.021362
# Epoch[46/100], loss: 0.021344
# Epoch[47/100], loss: 0.021328
# Epoch[48/100], loss: 0.021313
# Epoch[49/100], loss: 0.021300
# Epoch[50/100], loss: 0.021288
# Epoch[51/100], loss: 0.021277
# Epoch[52/100], loss: 0.021267
# Epoch[53/100], loss: 0.021258
# Epoch[54/100], loss: 0.021250
# Epoch[55/100], loss: 0.021243
# Epoch[56/100], loss: 0.021236
# Epoch[57/100], loss: 0.021230
# Epoch[58/100], loss: 0.021224
# Epoch[59/100], loss: 0.021219
# Epoch[60/100], loss: 0.021215
# Epoch[61/100], loss: 0.021210
# Epoch[62/100], loss: 0.021207
# Epoch[63/100], loss: 0.021203
# Epoch[64/100], loss: 0.021200
# Epoch[65/100], loss: 0.021197
# Epoch[66/100], loss: 0.021195
# Epoch[67/100], loss: 0.021192
# Epoch[68/100], loss: 0.021190
# Epoch[69/100], loss: 0.021188
# Epoch[70/100], loss: 0.021187
# Epoch[71/100], loss: 0.021185
# Epoch[72/100], loss: 0.021184
# Epoch[73/100], loss: 0.021182
# Epoch[74/100], loss: 0.021181
# Epoch[75/100], loss: 0.021180
# Epoch[76/100], loss: 0.021179
# Epoch[77/100], loss: 0.021178
# Epoch[78/100], loss: 0.021177
# Epoch[79/100], loss: 0.021177
# Epoch[80/100], loss: 0.021176
# Epoch[81/100], loss: 0.021175
# Epoch[82/100], loss: 0.021175
# Epoch[83/100], loss: 0.021174
# Epoch[84/100], loss: 0.021174
# Epoch[85/100], loss: 0.021173
# Epoch[86/100], loss: 0.021173
# Epoch[87/100], loss: 0.021173
# Epoch[88/100], loss: 0.021172
# Epoch[89/100], loss: 0.021172
# Epoch[90/100], loss: 0.021172
# Epoch[91/100], loss: 0.021172
# Epoch[92/100], loss: 0.021171
# Epoch[93/100], loss: 0.021171
# Epoch[94/100], loss: 0.021171
# Epoch[95/100], loss: 0.021171
# Epoch[96/100], loss: 0.021171
# Epoch[97/100], loss: 0.021171
# Epoch[98/100], loss: 0.021171
# Epoch[99/100], loss: 0.021170
# Epoch[100/100], loss: 0.021170

# %%
print(f'Peso Ótimo: \t {loss_otimo}')
print(f'Peso Treinado: \t {loss}')
# Out:
# Peso Ótimo: 	 0.021169424119097165
# Peso Treinado: 	 0.021170369703739575
